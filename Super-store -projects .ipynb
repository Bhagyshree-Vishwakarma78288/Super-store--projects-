# %% [markdown]
# # Superstore project

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel(r"Superstore_USA orignal.xlsx")
df.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#         City Postal Code Order Date  Year Month  Ship Date Profit  \
# 0    Addison       60101 2012-05-28  2012   May 2012-05-30   1.32
# 1  Anacortes       98221 2010-07-07  2010   Jul 2010-07-08   4.56
#
#    Quantity ordered new  Sales  Order ID
# 0                     2   5.90     88525
# 1                     4  13.01     88522
#
# [2 rows x 26 columns]

# %%
df.shape
# Out:
# (9426, 26)

# %%
# find out missing value

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Year                    0
# Month                   0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
df.fillna(df["Product Base Margin"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Year                    0
# Month                   0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# # order priority

# %%
df["Order Priority"].value_counts()
# Out:
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: Order Priority, dtype: int64

# %%
df["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
df["Order Priority"] = df["Order Priority"].replace('Critical ','Critical')
df["Order Priority"]
# Out:
# 0       Not Specified
# 1                High
# 2       Not Specified
# 3       Not Specified
# 4       Not Specified
#             ...
# 9421         Critical
# 9422         Critical
# 9423    Not Specified
# 9424             High
# 9425    Not Specified
# Name: Order Priority, Length: 9426, dtype: object

# %%
ax = sns.countplot(x="Order Priority",data=df)
for bars in ax.containers:
    ax.bar_label(bars) 
plt.figure(figsize=(5,3)) 
plt.title("count of Order Priority")
plt.savefig("count of Order Priority.jpg")
plt.show()

# %% [markdown]
# # Ship Mode

# %%
df["Ship Mode"].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
ax = sns.countplot(x="Ship Mode",data=df)  # bar chart
for bars in ax.containers:
    ax.bar_label(bars) 
plt.title("count of Ship mode")
plt.figure(figsize=(5,3))
plt.show()

# %%
x = df["Ship Mode"].value_counts().index
y = df["Ship Mode"].value_counts().values

# %%
plt.pie(y,labels=x,autopct="%0.2f%%") 
plt.figure(figsize=(5,4))
plt.legend() 
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # ship mode and product cartegory

# %%
ax = sns.countplot(x="Ship Mode",data=df,hue="Product Category")
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("ship mode category wise")
plt.figure(figsize=(5,3))
plt.show()

# %%
df["Customer Segment"].value_counts()
# Out:
# Corporate         3375
# Home Office       2316
# Consumer          1894
# Small Business    1841
# Name: Customer Segment, dtype: int64

# %%
ax = sns.countplot(x = "Customer Segment",data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.figure(figsize=(8,4))
plt.show()

# %%
sns.countplot(x = "Product Category",data=df[df["Product Category"]=="Office Supplies"],hue="Product Sub-Category")
plt.figure(figsize=(15,4))
plt.show()

# %%
sns.countplot(x = "Product Category",data=df[df["Product Category"]=="Technology"],hue="Product Sub-Category")
plt.figure(figsize=(15,4))
plt.show()

# %%
sns.countplot(x = "Product Category",data=df[df["Product Category"]=="Furniture"],hue="Product Sub-Category")
plt.figure(figsize=(15,4))
plt.show()

# %%
df["Year"].value_counts()
# Out:
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: Year, dtype: int64

# %%
ax = sns.countplot(x="Year",data=df)
for bars in ax.containers:
    ax.bar_label(bars) 
plt.show()

# %%
sns.barplot(x="Year",y="Profit",data=df,estimator="sum")
plt.show()

# %%
sns.barplot(x="Product Category",y="Product Base Margin",data=df,estimator="sum")
plt.show()
